# %% [markdown]
# # Retraining StyleGAN2-PyTorch on Kaggle
#
# This notebook uses https://github.com/harryli0088/stylegan2-pytorch which is a fork of https://github.com/rosinality/stylegan2-pytorch
#
# ## Background
#
# This notebook uses the closed form factorization scripts to control for the output features using the latent space.

# %% [markdown]
# # Kaggle Setup
#
# You need to upload your image data to Kaggle as a Dataset. Once you do so, connect the notebook to the dataset. When you run the code block below, you should have access to the images in that dataset.
#
# Also you need to allow the notebook access to Internet and GPU:
#
#     - Right Sidebar > Settings > Verify phone number
#
#     - Right Sidebar > Settings > Accelerator > GPU
#
#     - Right Sidebar > Settings > Internet > On

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        break

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # Installation and Setup
#
# - Install the StyleGAN2 PyTorch repo
# - Install ninja (which apparently is necessary for PyTorch to use C++)
# - Create output directories for training

# %%
# !git clone https://github.com/harryli0088/stylegan2-pytorch.git
# !pip install ninja
# !mkdir sample checkpoint

# %% [markdown]
# # Extract Eigenvectors

# %%
# !python /kaggle/working/stylegan2-pytorch/closed_form_factorization.py /kaggle/input/018000diamondtransfergemstones211210/018000.pt

# %% [markdown]
# # Closed-Form Factorization

# %%
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 0 -d 5 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 1 -d 5 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 2 -d 5 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 3 -d 5 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 4 -d 5 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 5 -d 5 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 6 -d 5 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 7 -d 5 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 8 -d 5 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 9 -d 5 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 10 -d 10 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 11 -d 10 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 12 -d 10 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 13 -d 10 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 14 -d 10 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 15 -d 10 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 16 -d 10 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 17 -d 10 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 18 -d 10 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 19 -d 10 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
# !python /kaggle/working/stylegan2-pytorch/apply_factor.py -i 20 -d 10 -n 10 --ckpt /kaggle/input/stylegan2-diamond-9000/009000.pt factor.pt
